# %%
import os
import math
import skimage
import scipy as sp
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import glob
import SimpleITK as sitk
from nibabel import processing
import pydicom
# Out:
# C:\Users\e.lavrova\AppData\Local\Continuum\anaconda3\lib\site-packages\dicom\__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
counter = 0
series_descr = []
protocol_name = []
acq_contrast = []
seque_name = []

for item in os.listdir(cd):
    path = os.path.join(cd, item)
    if (os.path.isdir(path) and ('MUMC' in item)):
        print (path)
        for subitem in os.listdir(path + '/DICOM/'):
            subpath = os.path.join(path + '/DICOM/', subitem)
            try:
                ds = pydicom.read_file(subpath, force = True)
                try:
                    sd = ds.SeriesDescription
                    try:
                        if ((sd == 'T1W 2D DIR') or (sd == 'T1W 2D DIR + contrast') or (sd == 'T1-TFE') or 
                            (sd == '3DTOF') or (sd == 'T2W MS TSE')):
                            copyfile(subpath, 'Z:/Lisa/PARISK/' + item + '/' + subitem)
                    except:
                        print ('cannot copy')
                except:
                    print ('cannot find description')
            except:
                print (subpath, ' cannot read')
# Out:
# F:/MRI/MRI/MUMC001
# F:/MRI/MRI/MUMC001/DICOM/00000001  cannot read
# F:/MRI/MRI/MUMC001/DICOM/00000002  cannot read
# F:/MRI/MRI/MUMC002
# F:/MRI/MRI/MUMC002/DICOM/00000001  cannot read
# F:/MRI/MRI/MUMC002/DICOM/00000002  cannot read
# cannot find description
# F:/MRI/MRI/MUMC003
# F:/MRI/MRI/MUMC003/DICOM/00000001  cannot read
# F:/MRI/MRI/MUMC003/DICOM/00000002  cannot read
# F:/MRI/MRI/MUMC004
# F:/MRI/MRI/MUMC004/DICOM/00000001  cannot read
# F:/MRI/MRI/MUMC004/DICOM/00000002  cannot read
# F:/MRI/MRI/MUMC005
# F:/MRI/MRI/MUMC005/DICOM/00000001  cannot read
# F:/MRI/MRI/MUMC005/DICOM/00000002  cannot read
# cannot find description
# F:/MRI/MRI/MUMC006
# F:/MRI/MRI/MUMC006/DICOM/00000001  cannot read
# F:/MRI/MRI/MUMC006/DICOM/00000002  cannot read
# F:/MRI/MRI/MUMC007
# cannot find description
# F:/MRI/MRI/MUMC008
# cannot find description
# F:/MRI/MRI/MUMC009
# cannot find description
# F:/MRI/MRI/MUMC010
# cannot copy
# cannot find description
# cannot find description
# ...

# %%
ds = pydicom.read_file("Z:\Lisa\PARISK\MUMC001\T2W MS TSE00001.dcm", force = True)

# %%
cd = 'Z:\Lisa\PARISK'

body_parts = []

for item in os.listdir(cd):
    path = os.path.join(cd, item)
    if (os.path.isdir(path)):
        print (path)
        for subitem in os.listdir(path):
            subpath = os.path.join(path, subitem)
            try:
                ds = pydicom.read_file(subpath, force = True)
                body_parts.append(ds.BodyPartExamined)
            except:
                print(subpath+' cannot read')
# Out:
# Z:\Lisa\PARISK\MUMC001
# Z:\Lisa\PARISK\MUMC001\MUMC001_STD338230040_SER1101_ACQ11.con cannot read
# Z:\Lisa\PARISK\MUMC001\MUMC001_STD338230040_SER1201_ACQ12.con cannot read
# Z:\Lisa\PARISK\MUMC001\MUMC001_STD338230040_SER1301_ACQ13.con cannot read
# Z:\Lisa\PARISK\MUMC001\MUMC001_STD338230040_SER1401_ACQ14.con cannot read
# Z:\Lisa\PARISK\MUMC001\MUMC001_STD338230040_SER1501_ACQ15.con cannot read
# Z:\Lisa\PARISK\MUMC001\MUMC001_STD338230040_SER1601_ACQ16.con cannot read
# Z:\Lisa\PARISK\MUMC001\T1W 2D DIR00006.dcm cannot read
# Z:\Lisa\PARISK\MUMC002
# Z:\Lisa\PARISK\MUMC002\3DTOF00007.dcm cannot read
# Z:\Lisa\PARISK\MUMC002\3DTOF00010.dcm cannot read
# Z:\Lisa\PARISK\MUMC002\3DTOF00011.dcm cannot read
# Z:\Lisa\PARISK\MUMC002\3DTOF00012.dcm cannot read
# Z:\Lisa\PARISK\MUMC002\3DTOF00013.dcm cannot read
# Z:\Lisa\PARISK\MUMC002\3DTOF00015.dcm cannot read
# Z:\Lisa\PARISK\MUMC002\3DTOF00019.dcm cannot read
# ...

# %%
body_parts
# Out:
# ['NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
#  'NECK',
# ...

# %%
np.unique(np.array(body_parts))
# Out:
# array(['BRAIN', 'LIVER', 'NECK'], dtype='<U5')
